# %%
#using https://machinelearningmastery.com/multinomial-logistic-regression-with-python/
import pandas as pd
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression

#technique of loading in and making variables into numbers stolen from Izzy, lmk if youre cool with that
data = pd.read_csv('/Users/nataliesimkins/Downloads/cleaned_dummy_dataset.csv')
data_full = pd.read_csv('/Users/nataliesimkins/Downloads/cleansoybean_csv.csv')
data['Class'] = data_full['class']
data = data.loc[:,'plant-growth_abnorm':]
data.tail()

data_num = data.replace({False: 0, True: 1})
data_num = data_num.drop(columns=['Class'])
data_num

#proof that it works example
X = data_num.drop(['roots_rotted'],axis=1)
y = data_num['roots_rotted']

#running the logistic regression
model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
ModelEvalProcedure = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
ModelAccuracyScores = cross_val_score(model, X, y, scoring='accuracy', cv=ModelEvalProcedure, n_jobs=-1)
print('Mean Accuracy: %.3f (%.3f)' % (mean(ModelAccuracyScores), std(ModelAccuracyScores)))

#fit model+predict class of first observation
result = model.fit(X, y)
row = X.iloc[0:1, :]
yhat = model.predict_proba(row)
print('Predicted Probabilities: %s' % yhat[0])

yhat = model.predict(row)
print('Predicted Class: %d' % yhat[0])
# Out:
# Mean Accuracy: 0.969 (0.022)
# Predicted Probabilities: [0.98163725 0.01836275]
# Predicted Class: 0

# %%
#trying to make it compare class to the numbers bc if i understand correctly, class is the disease the plant has and the one we want to predict
#print(data)
dataNoNA = data.dropna()
print(dataNoNA)

n = len(pd.unique(dataNoNA['Class']))
print("Unique values in class:", n)
#since there are only 15 unique values for class, the current plan is to assign each of them a number 1-15 and then once it does the analysis, re-assign their names so we know how well it did.

Xclass = dataNoNA
yclass = dataNoNA['Class']

print(Xclass.shape,yclass.shape)


model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
#CModelEvalProcedure = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
#CModelAccuracyScores = cross_val_score(model, Xclass, yclass, scoring='accuracy', cv=ModelEvalProcedure, n_jobs=-1)
#print('Mean Accuracy: %.3f (%.3f)' % (mean(ModelAccuracyScores), std(ModelAccuracyScores)))

#fit model+predict class of first observation
#Cresult = model.fit(X, y)
#Crow = X.iloc[0:1, :]
#Cyhat = model.predict_proba(row)
#print('Predicted Probabilities: %s' % yhat[0])

#Cyhat = model.predict(row)
#print('Predicted Class: %d' % yhat[0])
# Out:
#      plant-growth_abnorm  leafspots-halo_no-yellow-halos  \
# 0                   True                           False
# 1                   True                           False
# 2                   True                           False
# 3                   True                           False
# 4                   True                           False
# ..                   ...                             ...
# 557                False                            True
# 558                False                            True
# 559                False                            True
# 560                False                            True
# 561                False                            True
#
#      leafspots-marg_w-s-marg  leafspot-size_gt-1/8  leaf-mild_absent  \
# 0                      False                 False              True
# 1                      False                 False              True
# 2                      False                 False              True
# 3                      False                 False              True
# 4                      False                 False              True
# ..                       ...                   ...               ...
# 557                     True                  True              True
# 558                     True                  True              True
# 559                     True                  True              True
# 560                     True                  True              True
# 561                     True                  True              True
#
#      stem-cankers_absent  canker-lesion_dk-brown-blk  fruiting-bodies_absent  \
# 0                  False                       False                   False
# 1                  False                       False                   False
# 2                  False                       False                   False
# 3                  False                       False                   False
# 4                  False                       False                   False
# ..                   ...                         ...                     ...
# 557                 True                       False                    True
# 558                 True                       False                    True
# 559                 True                       False                    True
# 560                 True                       False                    True
# 561                 True                       False                    True
#
#      fruiting-bodies_present  external-decay_absent  int-discolor_brown  \
# 0                       True                  False               False
# 1                       True                  False               False
# 2                       True                  False               False
# 3                       True                  False               False
# 4                       True                  False               False
# ..                       ...                    ...                 ...
# 557                    False                   True               False
# 558                    False                   True               False
# 559                    False                   True               False
# 560                    False                   True               False
# 561                    False                   True               False
#
#      int-discolor_none  fruit-pods_diseased  fruit-pods_norm  \
# 0                 True                False             True
# 1                 True                False             True
# 2                 True                False             True
# 3                 True                False             True
# 4                 True                False             True
# ..                 ...                  ...              ...
# 557               True                False             True
# 558               True                False             True
# 559               True                False             True
# 560               True                False             True
# 561               True                False             True
#
#      fruit-spots_absent  fruit-spots_colored  mold-growth_absent  \
# 0                 False                False                True
# 1                 False                False                True
# 2                 False                False                True
# 3                 False                False                True
# 4                 False                False                True
# ..                  ...                  ...                 ...
# 557                True                False                True
# 558                True                False                True
# 559                True                False                True
# 560                True                False                True
# 561                True                False                True
#
#      roots_rotted                  Class
# 0           False  diaporthe-stem-canker
# 1           False  diaporthe-stem-canker
# 2           False  diaporthe-stem-canker
# 3           False  diaporthe-stem-canker
# 4           False  diaporthe-stem-canker
# ..            ...                    ...
# 557         False     frog-eye-leaf-spot
# 558         False     frog-eye-leaf-spot
# 559         False     frog-eye-leaf-spot
# 560         False     frog-eye-leaf-spot
# 561         False     frog-eye-leaf-spot
#
# [562 rows x 19 columns]
# Unique values in class: 15
# (562, 19) (562,)
